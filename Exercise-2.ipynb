# %% [markdown]
# # Visualizing Chipotle's Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv(url, sep ='\t')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. Create a histogram of the top 5 items bought

# %%
item_counts = chipo.groupby('item_name')['quantity'].sum().sort_values(ascending=False).head(5)
histogram_data = chipo[chipo['item_name'].isin(item_counts.index)]
plt.hist(histogram_data['item_name'], bins=10)
# Out:
# (array([726.,   0., 368.,   0.,   0., 479.,   0., 553.,   0., 301.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Step 6. Create a scatterplot with the number of items orderered per order price
# #### Hint: Price should be in the X-axis and Items ordered in the Y-axis

# %%
order_summary = chipo.groupby('item_price')['quantity'].sum()
order_prices = order_summary.index
ordered_items = order_summary.values

plt.scatter(order_prices, ordered_items)

# %% [markdown]
# ### Step 7. BONUS: Create a question and a graph to answer your own question.
#
# ### Create a pie chart of the top five items bought and their sale revenue

# %%
# y = chipo.groupby('item_name')['quantity'].sum().head(5)
y= item_counts
x = y.index

y.plot(kind="pie", autopct='%1.1f%%', title='Top Sellers')
# Out:
# <Axes: title={'center': 'Top Sellers'}, ylabel='quantity'>
